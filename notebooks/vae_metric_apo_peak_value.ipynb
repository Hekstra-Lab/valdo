# %%
import pandas as pd
import numpy as np
import gemmi
import reciprocalspaceship as rs
from tqdm import tqdm
import glob, os
# Out:
# /n/hekstra_lab/people/dhekstra/conda_envs/valdo-gpu/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
file_path = './ligand_cif_to_dataset_mapping.txt'

apo_samples = []
with open(file_path, 'r') as file:
    for line in file:
        if not line.strip().endswith('.cif'):
            apo_samples.append(line.strip()[-5:-1])

# %%
len(apo_samples)
# Out:
# 41

# %%
my_dir                             = "/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/"
basepath                           = my_dir + 'pipeline/'

# %% [markdown]
# ### VAE METRIC APO PEAK VALUE

# %%
vae_reconstructed_with_phases_path = basepath + 'vae/reconstructed_w_phases/'

# %%
peak_values = []
column='WDF'
for pdbid in tqdm(apo_samples):
    # try:
    # Change the following line to the mtzs files your model created
    print(glob.glob(os.path.join(vae_reconstructed_with_phases_path, f"{pdbid}*.mtz")))
    try:
        mtz_file = gemmi.read_mtz_file(glob.glob(os.path.join(vae_reconstructed_with_phases_path, f"{pdbid}*.mtz"))[0])
        real_grid = mtz_file.transform_f_phi_to_map(column, 'refine_PH2FOFCWT', sample_rate=3.0)
        real_grid.normalize()
    
        peak_values.append(np.max(real_grid))
    except:
        print(f"Can't handle {pdbid}")
# Out:
#   5%|██▍                                                | 2/41 [00:00<00:02, 16.26it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0001_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0002_1.mtz']
# []
# Can't handle 0003
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0004_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0006_0.mtz']
#  15%|███████▍                                           | 6/41 [00:00<00:01, 21.73it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0009_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0010_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0011_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0012_0.mtz']
#  29%|██████████████▋                                   | 12/41 [00:00<00:01, 20.98it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0013_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0014_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0015_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0017_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0018_0.mtz']
#  44%|█████████████████████▉                            | 18/41 [00:00<00:01, 21.78it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0019_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0020_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0021_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0022_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0023_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0024_0.mtz']
#  59%|█████████████████████████████▎                    | 24/41 [00:01<00:00, 23.65it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0025_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0027_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0028_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0125_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0126_0.mtz']
#  66%|████████████████████████████████▉                 | 27/41 [00:01<00:00, 21.35it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0127_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0128_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0129_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0130_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0131_0.mtz']
#  80%|████████████████████████████████████████▏         | 33/41 [00:01<00:00, 21.03it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0132_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0133_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0134_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0135_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0136_1.mtz']
#  95%|███████████████████████████████████████████████▌  | 39/41 [00:01<00:00, 22.29it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0138_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0140_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0141_0.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0142_1.mtz']
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/0144_1.mtz']
# 100%|██████████████████████████████████████████████████| 41/41 [00:01<00:00, 21.45it/s]
# ['/n/holyscratch01/hekstra_lab/dhekstra/valdo-tests/pipeline/vae/reconstructed_w_phases/1102_0.mtz']

# %%
print("Mean Highest Peak Value in Apo models: ", np.mean(peak_values))
# Out:
# Mean Highest Peak Value in Apo models:  7.319037

# %%
for ld in [2, 3, 4, 5, 6, 7, 8, 9]:
    
    for activation in ['relu', 'tanh']:

        peak_values = []

        for pdbid in apo_samples:

            # Change the following line to the mtzs files your model created
            mtz_file = gemmi.read_mtz_file(f'../../pipeline/vae/{activation}/recons-{ld}-phases/PTP1B-y{pdbid}_mrflagsref_idxs_scaled.mtz')

            real_grid = mtz_file.transform_f_phi_to_map('F-obs-diff', 'refine_PH2FOFCWT', sample_rate=3.0)
            real_grid.normalize()

            peak_values.append(np.max(real_grid))
            
        print(activation, ld, np.mean(peak_values))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 10
#       5 peak_values = []
#       7 for pdbid in apo_samples:
#       8
#       9     # Change the following line to the mtzs files your model created
# ---> 10     mtz_file = gemmi.read_mtz_file(f'../../pipeline/vae/{activation}/recons-{ld}-phases/PTP1B-y{pdbid}_mrflagsref_idxs_scaled.mtz')
#      12     real_grid = mtz_file.transform_f_phi_to_map('F-obs-diff', 'refine_PH2FOFCWT', sample_rate=3.0)
#      13     real_grid.normalize()
#
# FileNotFoundError: [Errno 2] Failed to open ../../pipeline/vae/relu/recons-2-phases/PTP1B-y0001_mrflagsref_idxs_scaled.mtz: No such file or directory

# %% [markdown]
# ### Zmap mean peak value as metric

# %%
z_maps_path                        = basepath + 'data/z_maps/'

# %%
peak_values = []

for pdbid in tqdm(apo_samples):
    
    # Change the following line to the mtzs files your model created
    zmap = gemmi.read_ccp4_map(z_maps_path + f'PTP1B-y{pdbid}-z_map.native.ccp4')

    real_grid = zmap.grid
    real_grid.normalize()

    peak_values.append(np.max(real_grid))

# %%
### Mean peak value as metric
print("Mean Highest Peak Value in Apo models: ", np.mean(peak_values))
# Out:
# Mean Highest Peak Value in Apo models:  5.016709
