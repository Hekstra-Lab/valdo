# %%
import pickle
import numpy as np

# %%
def load_results(filepath):
    with open(filepath, 'rb') as f:
        D = pickle.load(f)
        loss_train = D['loss_train']
        loss_test = D['loss_test']
        return loss_train, loss_test

# %%
loss_train, loss_test = load_results('../vae-optimization/latent-dim-2-nov4-4000.pkl')
train_loss_array, test_loss_array = np.array(loss_train), np.array(loss_test)

# %% [raw]
# def plot_losses(losses, test=False):
#     fig, axs = plt.subplots(nrows=4, ncols=1, figsize=[10,15])
#     ax = axs.reshape(-1)
#
#     ax[0].plot(loss_array[:,3], label='Mean Least Squares')
#     ax[0].set_xlabel("Steps")
#     ax[0].legend()
#
#     ax[1].plot(loss_array[:,1], label='Negative Log Likelihood')
#     ax[1].set_xlabel("Steps")
#     ax[1].legend()
#
#     ax[2].plot(loss_array[:,2], label='KL Divergence')
#     ax[2].set_xlabel("Steps")
#     ax[2].legend()
#
#     ax[3].plot(loss_array[:,0], label='Total Loss')
#     ax[3].set_xlabel("Steps")
#     ax[3].legend()
#
#     plt.show()

# %%
plot_losses(loss_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_225958/292417852.py in <module>
# ----> 1 plot_losses(loss_train)
#
# NameError: name 'plot_losses' is not defined
