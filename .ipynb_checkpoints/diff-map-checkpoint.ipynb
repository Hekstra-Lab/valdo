# %% [markdown]
# ## Imports / Helper Functions

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import reciprocalspaceship as rs
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, auc
from sklearn.model_selection import train_test_split
import numpy as np
import json
from scipy import stats
import random
import math
import gemmi
from sklearn.decomposition import PCA
import time
import sys
from scipy.stats import pearsonr, skew, kurtosis
import pickle
from tqdm.notebook import tqdm
import os
import re
# scaled - reconstructed

# %% [markdown]
# ### Ligand Cif Processing

# %%
ligand_cif = []

with open('../PTP1B_DK/ligand_cif_to_dataset_mapping.txt') as f:
    lines = f.readlines()
    
for line in lines:
    dataset, ligands = line[:-1].split(":")
    ligands = list(filter(None,ligands.split(" ")))
    ligand_cif.append([dataset, ligands, 0 if len(ligands) > 0 else 1])
    
ligand_cif = pd.DataFrame(ligand_cif, columns=["Dataset", "Ligands", "Apo"])

apo_samples = ligand_cif[ligand_cif['Apo'] == 1]['Dataset'].tolist()
apo_samples = [sample.split('y')[1] for sample in apo_samples]

samples = ligand_cif['Dataset'].tolist()
samples = [sample.split('y')[1] for sample in samples]

# %%
with open('../PTP1B_DK/samples.json', 'w') as f:
    json.dump(samples, f)

# %%
with open('../PTP1B_DK/apo_samples.json', 'w') as f:
    json.dump(apo_samples, f)

# %% [markdown]
# ### Moving to Cell

# %%
def move2cell(cartesian_coordinates, unit_cell, fractionalize=True):
    '''
    Move your points into a unitcell with translational vectors
    
    Parameters
    ----------
    cartesian_coordinates: array-like
        [N_points, 3], cartesian positions of points you want to move
        
    unit_cell, gemmi.UnitCell
        A gemmi unitcell instance
    
    fractionalize: boolean, default True
        If True, output coordinates will be fractional; Or will be cartesians
    
    Returns
    -------
    array-like, coordinates inside the unitcell
    '''
    o2f_matrix = np.array(unit_cell.fractionalization_matrix)
    frac_pos = np.dot(cartesian_coordinates, o2f_matrix.T) 
    frac_pos_incell = frac_pos % 1
    if fractionalize:
        return frac_pos_incell
    else:
        f2o_matrix = np.array(unit_cell.orthogonalization_matrix)
        return np.dot(frac_pos_incell, f2o_matrix.T)

# %% [markdown]
# ### Abstracted Automatic Pipeline

# %%
def generate_diff_map_stats(path_to_mtzs, diff_col, phase_col):

    # Assumes file name is in PTP1B-y{sample}_mrflagsref... form.

    stats = []
    
    for file_path in tqdm(os.listdir(path_to_mtzs)):

        try:
            # check if mtz exists, read diff_map, reindex if necessary
            diff_map = rs.read_mtz(path_to_mtzs + file_path)[[diff_col, phase_col]].dropna()
            sample = re.search('[0-9]{4}', file_path).group()

        except: 
            continue

        diff_map_gemmi=diff_map.to_gemmi()
        diff_map_grid = diff_map_gemmi.transform_f_phi_to_map(diff_col, phase_col, sample_rate=3)
        diff_map_grid.normalize()

        ######################################## COMPUTE BASIC STATS ################################################################
        diff_map_array = np.array(diff_map_grid).flatten()
        mean, sigma = np.mean(diff_map_array), np.std(diff_map_array)

        sample_stats = {
            "sample"  :    sample,
            "reindex" :    0 if sample in reindexed["0"] else 1,
            "bound"   :    1 if sample in bound_samples else 0,
            "mean"    :    mean,
            "sd"      :    sigma,
            "skew"    :    skew(diff_map_array),
            "kurtosis":    kurtosis(diff_map_array)

        }

        stats.append(sample_stats)
    
    return pd.DataFrame(stats)

# %%
def generate_diff_map_blobs(path_to_mtzs, path_to_models, diff_col, phase_col):
    
    peaks = []
    
    base_model_path = path_to_models + os.listdir(path_to_models)[0]
    base_diff_path = path_to_mtzs + os.listdir(path_to_mtzs)[0]
    
    def generate_file_name(base, sample):
        return re.split('[0-9]{4}', base)[0] + str(sample) + re.split('[0-9]{4}', base)[1]  
    
    for file_path in tqdm(os.listdir(path_to_mtzs)):

        try:
            # check if mtz exists, read diff_map, reindex if necessary
            diff_map = rs.read_mtz(path_to_mtzs + file_path)[[diff_col, phase_col]].dropna()
            sample = re.search('[0-9]{4}', file_path).group()
            
            # read input model
            structure = gemmi.read_pdb(generate_file_name(base_model_path, sample))

        except: 
            continue

        diff_map_gemmi=diff_map.to_gemmi()
        grid = diff_map_gemmi.transform_f_phi_to_map(diff_col, phase_col, sample_rate=3)
        grid.normalize()

        mean, sigma = np.mean(np.array(grid)), np.std(np.array(grid))

        # minimum requirements
        blobs = gemmi.find_blobs_by_flood_fill(grid, cutoff=5.5, min_volume=10, min_score=0, min_peak=7.5, negate=True)
        
        ns = gemmi.NeighborSearch(structure[0], structure.cell, 5).populate()
        peaks = []
        count = 0

        for blob in blobs:
            #This is a list of weird pointer objects. It is safest to convert them `gemmi.CRA` objects (see below)
            marks = ns.find_atoms(blob.centroid)
            if len(marks) == 0:
                continue

            cra = dist = None
            for mark in marks:
                image_idx = mark.image_idx
                cra = mark.to_cra(structure[0])
                dist = structure.cell.find_nearest_pbc_image(blob.centroid, _cra.atom.pos, mark.image_idx).dist()

                record = {
                    "sample"  :    sample,
                    "bound"   :    1 if sample in bound_samples else 0,
                    "reindex" :    0 if sample in reindexed["0"] else 1,
                    "chain"   :    cra.chain.name,
                    "seqid"   :    cra.residue.seqid.num,
                    "residue" :    cra.residue.name,
                    "atom"    :    cra.atom.name,
                    "element" :    cra.atom.element.name,
                    "dist"    :    dist,
                    "peakz"   :    (blob.peak_value-mean)/sigma,
                    "scorez"  :    (blob.score-mean)/sigma,
                    "peak"    :    blob.peak_value,
                    "score"   :    blob.score,
                    "cenx"    :    blob.centroid.x,
                    "ceny"    :    blob.centroid.y,
                    "cenz"    :    blob.centroid.x,
                    "coordx"  :    cra.atom.pos.x,
                    "coordy"  :    cra.atom.pos.y,
                    "coordz"  :    cra.atom.pos.z,
                }
                if negate:
                    negative_keys = ['peak', 'peakz', 'score', 'scorez']
                    for k in negative_keys:
                        record[k] = -record[k]
                        
            peaks.append(record)
    return pd.DataFrame(peaks)

# %% [markdown]
# ## Scratch-work

# %% [markdown]
# ### Finding Blobs (Scratch-work)

# %% [markdown]
# #### Verifying FFT

# %%
data = rs.read_mtz('../PTP1B_DK/recons_mtzs/PTP1B-y0049_mrflagsref_idxs_recons.mtz')[["F-obs-diff", "PHIFOFCWT"]].dropna()
print(data.spacegroup)
data2 = data.copy()
data2.spacegroup = gemmi.SpaceGroup('P 1')

sample_data = data.to_gemmi()
sample_data2 = data2.to_gemmi()

map1 = sample_data.transform_f_phi_to_map("F-obs-diff", "PHIFOFCWT", sample_rate=3)
map2 = sample_data2.transform_f_phi_to_map("F-obs-diff", "PHIFOFCWT", sample_rate=3)

# map1 == map2?
# Out:
# <gemmi.SpaceGroup("P 31 2 1")>

# %%
if (map1 == map2):
    print("hi")
else:
    print("Not same")
# Out:
# Not same

# %% [markdown]
# #### FFT + find_blobs_by_flood_fill

# %%
long_names = {
    "chain"   : "Chain",
    "seqid"   : "SeqID",
    "residue" : "Residue",
    "name"    : "Atom Name",
    "dist"    : "Dist (Å)",
    "peak"    : "Peak Value",
    "peakz"   : "Peak Value (Z-score)",
    "score"   : "Peak Score",
    "scorez"  : "Peak Score (Z-score)",
    "cenx"    : "Centroid (x)",
    "ceny"    : "Centroid (y)",
    "cenz"    : "Centroid (z)",
    "coordx"  : "Coord (x)",
    "coordy"  : "Coord (y)",
    "coordz"  : "Coord (z)",
}

# %%
sample=rs.read_mtz('../PTP1B_DK/recons_mtzs/PTP1B-y0049_mrflagsref_idxs_recons.mtz')[["F-obs-diff", "PHIFOFCWT"]].dropna()
structure = gemmi.read_pdb("../PTP1B_DK/bound_state_models/PTP1B-y0049_refmac_input.split.bound-state.pdb")

sample_gemmi=sample.to_gemmi()
grid = sample_gemmi.transform_f_phi_to_map("F-obs-diff", "PHIFOFCWT", sample_rate=3)
grid.normalize()

mean, sigma = np.mean(np.array(grid)), np.std(np.array(grid))

# minimum requirements
blobs = gemmi.find_blobs_by_flood_fill(grid, cutoff=5.5, min_volume=10, min_score=0, min_peak=7.5, negate=False)

# %%
blobs

# %%
plt.hist(np.array(grid).flatten(), bins=100)
plt.yscale("log")
plt.show()

# %%
blobs[0].peak_value
# Out:
# 12.113320350646973

# %%
blobs[0].centroid
# Out:
# <gemmi.Position(-11.3424, 61.0433, 11.3358)>

# %% [markdown]
# #### Finds Atoms Near Blobs

# %%
use_long_names = False
sort_by_key='peakz'
negate=True

ns = gemmi.NeighborSearch(structure[0], structure.cell, 5).populate()
peaks = []
count = 0

for blob in blobs:
    #This is a list of weird pointer objects. It is safest to convert them `gemmi.CRA` objects (see below)
    marks = ns.find_atoms(blob.centroid)
    if len(marks) == 0:
        continue

    cra = dist = None
    for mark in marks:
        image_idx = mark.image_idx
        cra = mark.to_cra(structure[0])
        dist = structure.cell.find_nearest_pbc_image(blob.centroid, _cra.atom.pos, mark.image_idx).dist()

        record = {
            "chain"   :    cra.chain.name,
            "seqid"   :    cra.residue.seqid.num,
            "residue" :    cra.residue.name,
            "atom"    :    cra.atom.name,
            "element" :    cra.atom.element.name,
            "dist"    :    dist,
            "peakz"   :    (blob.peak_value-mean)/sigma,
            "scorez"  :    (blob.score-mean)/sigma,
            "peak"    :    blob.peak_value,
            "score"   :    blob.score,
            "cenx"    :    blob.centroid.x,
            "ceny"    :    blob.centroid.y,
            "cenz"    :    blob.centroid.x,
            "coordx"  :    cra.atom.pos.x,
            "coordy"  :    cra.atom.pos.y,
            "coordz"  :    cra.atom.pos.z,
        }
        if negate:
            negative_keys = ['peak', 'peakz', 'score', 'scorez']
            for k in negative_keys:
                record[k] = -record[k]
        peaks.append(record)
            

out = pd.DataFrame.from_records(peaks)

# %%
out
# Out:
#    chain  seqid residue  atom element      dist      peakz     scorez  \
# 0      A    105     ARG    HA       H  4.571734 -12.113325 -196.51567
# 1      A    105     ARG   HB2       H  4.571734 -12.113325 -196.51567
# 2      A    169     ARG    CG       C  4.571734 -12.113325 -196.51567
# 3      A    169     ARG    CD       C  4.571734 -12.113325 -196.51567
# 4      A    169     ARG   HG2       H  4.571734 -12.113325 -196.51567
# 5      A    169     ARG   HD3       H  4.571734 -12.113325 -196.51567
# 6      B      1     LIG   C14       C  4.571734 -12.113325 -196.51567
# 7      B      1     LIG   C15       C  4.571734 -12.113325 -196.51567
# 8      B      1     LIG   F17       F  4.571734 -12.113325 -196.51567
# 9      B      1     LIG  H151       H  4.571734 -12.113325 -196.51567
# 10     A    105     ARG    CD       C  4.571734 -12.113325 -196.51567
# 11     A    105     ARG    NE       N  4.571734 -12.113325 -196.51567
# 12     A    105     ARG    CZ       C  4.571734 -12.113325 -196.51567
# 13     A    105     ARG   NH2       N  4.571734 -12.113325 -196.51567
# 14     A    105     ARG   HD2       H  4.571734 -12.113325 -196.51567
# 15     A    105     ARG   HD3       H  4.571734 -12.113325 -196.51567
# 16     A    105     ARG  HH21       H  4.571734 -12.113325 -196.51567
# 17     A    169     ARG    CB       C  4.571734 -12.113325 -196.51567
# 18     A    169     ARG   HB3       H  4.571734 -12.113325 -196.51567
# 19     A    170     GLU     N       N  4.571734 -12.113325 -196.51567
# 20     A    170     GLU     O       O  4.571734 -12.113325 -196.51567
# 21     A    170     GLU     H       H  4.571734 -12.113325 -196.51567
# 22     A    170     GLU   HB3       H  4.571734 -12.113325 -196.51567
# 23     B      1     LIG   C16       C  4.571734 -12.113325 -196.51567
# 24     B      1     LIG  H161       H  4.571734 -12.113325 -196.51567
# 25     A    169     ARG    CA       C  4.571734 -12.113325 -196.51567
# 26     A    169     ARG    HA       H  4.571734 -12.113325 -196.51567
# 27     A    208     HIS   HD1       H  4.571734 -12.113325 -196.51567
# 28     A    208     HIS   CE1       C  4.571734 -12.113325 -196.51567
# 29     A    208     HIS   HE1       H  4.571734 -12.113325 -196.51567
# 30     B      1     LIG   C12       C  4.571734 -12.113325 -196.51567
# 31     B      1     LIG   C13       C  4.571734 -12.113325 -196.51567
# 32     B      1     LIG  H121       H  4.571734 -12.113325 -196.51567
# 33     B      1     LIG  H131       H  4.571734 -12.113325 -196.51567
# 34     B      1     LIG   C04       C  4.571734 -12.113325 -196.51567
# 35     B      1     LIG   C06       C  4.571734 -12.113325 -196.51567
# 36     B      1     LIG   C08       C  4.571734 -12.113325 -196.51567
# 37     B      1     LIG   C11       C  4.571734 -12.113325 -196.51567
# 38     B      1     LIG   N05       N  4.571734 -12.113325 -196.51567
# 39     B      1     LIG   N10       N  4.571734 -12.113325 -196.51567
# 40     B      1     LIG   O09       O  4.571734 -12.113325 -196.51567
# 41     B      1     LIG  H061       H  4.571734 -12.113325 -196.51567
# 42     B      1     LIG  H062       H  4.571734 -12.113325 -196.51567
# 43     B      1     LIG  H101       H  4.571734 -12.113325 -196.51567
# 44     S    266     HOH     O       O  4.571734 -12.113325 -196.51567
# 45     B      1     LIG  H042       H  4.571734 -12.113325 -196.51567
#
#         peak       score       cenx      ceny       cenz  coordx  coordy  \
# 0  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -34.380  19.772
# 1  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -35.657  19.786
# 2  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -27.506  18.759
# 3  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -28.378  17.514
# 4  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -27.554  18.996
# 5  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -29.224  17.651
# 6  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.732  17.795
# 7  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.731  18.996
# 8  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.753  16.590
# 9  -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.749  18.878
# 10 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -34.811  22.216
# 11 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -35.057  23.372
# 12 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -34.380  24.501
# 13 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -33.405  24.660
# 14 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -34.281  22.471
# 15 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -34.355  21.539
# 16 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -33.196  24.020
# 17 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -27.950  19.955
# 18 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -28.884  20.117
# 19 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -28.775  23.111
# 20 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.499  23.098
# 21 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -29.064  22.803
# 22 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -30.193  25.044
# 23 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.709  20.259
# 24 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.710  21.174
# 25 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -27.152  21.264
# 26 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -27.219  21.484
# 27 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -35.133  17.920
# 28 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -35.417  19.720
# 29 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -34.583  19.986
# 30 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.684  19.275
# 31 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.707  18.004
# 32 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.666  19.307
# 33 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.704  17.195
# 34 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -29.370  24.855
# 35 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.554  24.485
# 36 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -30.552  22.620
# 37 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.684  20.432
# 38 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -30.520  23.941
# 39 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.659  21.744
# 40 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -29.577  22.318
# 41 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -32.545  24.051
# 42 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -31.407  24.249
# 43 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -32.408  22.061
# 44 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -33.850  21.911
# 45 -12.11332 -196.515588 -11.342436  61.04328 -11.342436 -28.483  24.228
#
#     coordz
# 0   -7.955
# 1   -9.792
# 2   -9.363
# 3   -9.179
# 4  -10.302
# 5   -9.634
# 6  -10.151
# 7   -9.393
# 8   -9.609
# 9   -8.322
# 10  -9.710
# 11 -10.528
# 12 -10.459
# 13  -9.595
# 14  -8.939
# 15 -10.234
# 16  -9.059
# 17  -8.525
# 18  -8.731
# 19  -8.323
# 20  -7.913
# 21  -9.240
# 22  -9.265
# 23  -9.995
# 24  -9.421
# 25  -8.741
# 26  -9.693
# 27 -12.297
# 28 -12.975
# 29 -13.289
# 30 -12.129
# 31 -11.554
# 32 -13.210
# 33 -12.269
# 34 -12.265
# 35 -13.296
# 36 -11.817
# 37 -11.366
# 38 -12.452
# 39 -12.001
# 40 -11.126
# 41 -13.025
# 42 -14.372
# 43 -12.575
# 44 -14.089
# 45 -12.039

# %% [markdown]
# ### Automatic Pipeline (Scratch-work)

# %% [markdown]
# Calculating `skew` and `kurtosis` for each sample.

# %%
reindexed = json.load(open("../PTP1B_DK/mtzs_reindex/reindex.json"))

# %%
bound_samples = json.load(open("../PTP1B_DK/bound_samples.json"))

# %%
peaks = []
stats = []

for sample in tqdm(samples):
    
    try:
        # check if mtz exists, read diff_map, reindex if necessary
        diff_map = rs.read_mtz(f'../PTP1B_DK/recons_mtzs/PTP1B-y{sample}_mrflagsref_idxs_recons.mtz')[["F-obs-diff", "PHIFOFCWT"]].dropna()   
        # read input model
        structure = gemmi.read_pdb(f'../PTP1B_DK/pandda_input_models/PTP1B-y{sample}-pandda-input.pdb')
    
    except: 
        continue

    # if sample in reindexed["1"]:
    #     diff_map = diff_map.apply_symop(gemmi.Op("-x,-y,z"))
    
    # normalize diff map
    diff_map_gemmi=diff_map.to_gemmi()
    diff_map_grid = diff_map_gemmi.transform_f_phi_to_map("F-obs-diff", "PHIFOFCWT", sample_rate=3)
    diff_map_grid.normalize()
    
    ######################################## COMPUTE BASIC STATS ################################################################
    diff_map_array = np.array(diff_map_grid).flatten()
    mean, sigma = np.mean(diff_map_array), np.std(diff_map_array)
    
    sample_stats = {
        "sample"  :    sample,
        "reindex" :    0 if sample in reindexed["0"] else 1,
        "bound"   :    1 if sample in bound_samples else 0,
        "mean"    :    mean,
        "sd"      :    sigma,
        "skew"    :    skew(diff_map_array),
        "kurtosis":    kurtosis(diff_map_array)
        
    }
    
    stats.append(sample_stats)

    ##################################### FIND NEIGHBORS OF BLOBS ##############################################################
    # identify blobs
#     negate = True
#     blobs = gemmi.find_blobs_by_flood_fill(diff_map_grid, cutoff=5.5, min_volume=10, min_score=0, min_peak=7.5, negate=negate)
    
#     # neighbor search 
#     ns = gemmi.NeighborSearch(structure[0], structure.cell, 5).populate()
#     count = 0

#     for blob in blobs:

#         marks = ns.find_atoms(blob.centroid)
#         if len(marks) == 0:
#             continue

#         cra = dist = None
#         for mark in marks:
#             image_idx = mark.image_idx
#             _cra = mark.to_cra(structure[0])
#             _dist = structure.cell.find_nearest_pbc_image(blob.centroid, _cra.atom.pos, mark.image_idx).dist()
#             if cra is None:
#                 dist = _dist
#                 cra  = _cra
#             elif _dist < dist:
#                 dist = _dist
#                 cra  = _cra

#         record = {
#             "sample"  :    sample,
#             "reindex" :    0 if sample in reindexed["0"] else 1,
#             "bound"   :    1 if sample in bound_samples else 0,
#             "chain"   :    cra.chain.name,
#             "seqid"   :    cra.residue.seqid.num,
#             "residue" :    cra.residue.name,
#             "atom"    :    cra.atom.name,
#             "element" :    cra.atom.element.name,
#             "dist"    :    dist,
#             "peakz"   :    (blob.peak_value-mean)/sigma,
#             "scorez"  :    (blob.score-mean)/sigma,
#             "peak"    :    blob.peak_value,
#             "score"   :    blob.score,
#             "cenx"    :    blob.centroid.x,
#             "ceny"    :    blob.centroid.y,
#             "cenz"    :    blob.centroid.x,
#             "coordx"  :    cra.atom.pos.x,
#             "coordy"  :    cra.atom.pos.y,
#             "coordz"  :    cra.atom.pos.z,
#         }
#         if negate:
#             negative_keys = ['peak', 'peakz', 'score', 'scorez']
#             for k in negative_keys:
#                 record[k] = -record[k]
                
#         peaks.append(record)
# Out:
#   0%|          | 0/1958 [00:00<?, ?it/s]

# %%
stats_df = pd.DataFrame(stats)

# %%
stats_df
# Out:
#      sample  reindex  bound          mean   sd      skew  kurtosis
# 0      0001        1      0  2.700115e-10  1.0 -0.105626  0.580507
# 1      0002        1      0  3.000928e-10  1.0  0.055133  0.588118
# 2      0003        1      0  4.840323e-10  1.0  0.029848  0.217364
# 3      0004        0      0  5.768778e-10  1.0 -0.087208  0.445941
# 4      0006        0      0  1.317405e-08  1.0  0.022967  0.132931
# ...     ...      ...    ...           ...  ...       ...       ...
# 1621   1960        0      0 -4.622119e-10  1.0 -0.007248  0.337235
# 1622   1962        0      0  1.665224e-08  1.0  0.038455  0.248795
# 1623   1963        1      0 -4.024233e-10  1.0  0.048984  0.910579
# 1624   1964        1      0  3.669487e-10  1.0  0.115813  0.319613
# 1625   1966        0      0  6.208817e-11  1.0  0.032330  0.708906
#
# [1626 rows x 7 columns]

# %% [markdown]
# ## STATS

# %%
reindex_bound_stats = stats_df[(stats_df['reindex'] == 1) & (stats_df['bound'] == 1)]
reindex_not_bound_stats = stats_df[(stats_df['reindex'] == 1) & (stats_df['bound'] == 0)]
reindex_stats = stats_df[(stats_df['reindex'] == 1)]

no_reindex_bound_stats = stats_df[(stats_df['reindex'] == 0) & (stats_df['bound'] == 1)]
no_reindex_not_bound_stats = stats_df[(stats_df['reindex'] == 0) & (stats_df['bound'] == 0)]
no_reindex_stats = stats_df[(stats_df['reindex'] == 0)]

bound_stats = stats_df[(stats_df['bound'] == 1)]
not_bound_stats = stats_df[(stats_df['bound'] == 0)]

# %%
stats_df['apo'] = [1 if x in apo_samples else 0 for x in stats_df['sample']]
apo_stats = stats_df[stats_df['apo'] == 1]
holo_stats = stats_df[stats_df['apo'] == 0]

# %% [markdown]
# ### Scatter Plot (Skew + Kurtosis)

# %%
plt.scatter(not_bound_stats['skew'], not_bound_stats['kurtosis'], color="blue", label='Not Bound', alpha=0.1)
plt.scatter(bound_stats['skew'], bound_stats['kurtosis'], color="red", label='Bound', alpha=0.1)
plt.xlabel("Skew")
plt.ylabel("Kurtosis")
plt.title("Skew and Kurtosis in Classifying Bound vs Not")
plt.legend()
plt.show()

# %% [markdown]
# ### Histograms (Skew + Kurtosis)

# %%
plt.hist(not_bound_stats['skew'], color="blue", label='Not Bound', alpha=0.5, bins=30)
plt.hist(bound_stats['skew'], color="red", label='Bound', alpha=0.5, bins=30)
plt.xlabel("Skew")
plt.yscale("log")
plt.title("Skew in Classifying Bound vs Not")
plt.legend()
plt.show()

# %%
plt.hist(not_bound_stats['kurtosis'], color="blue", label='Not Bound', alpha=0.5, bins=30)
plt.hist(bound_stats['kurtosis'], color="red", label='Bound', alpha=0.5, bins=30)
plt.xlabel("Kurtosis")
plt.yscale("log")
plt.title("Kurtosis in Classifying Bound vs Not")
plt.legend()
plt.show()

# %%
plt.hist(holo_stats['kurtosis'], color="red", label='Holo', alpha=0.5, bins=30)
plt.hist(apo_stats['kurtosis'], color="blue", label='Apo', alpha=1, bins=30)
plt.xlabel("Kurtosis")
plt.yscale("log")
plt.title("Kurtosis in Classifying Apo vs Holo")
plt.legend()
plt.show()

# %%
plt.hist(holo_stats['skew'], color="red", label='Holo', alpha=0.5, bins=30, density=True)
plt.hist(apo_stats['skew'], color="blue", label='Apo', alpha=1, bins=30, density=True)
plt.xlabel("Skew")
plt.yscale("log")
plt.title("Skew in Classifying Apo vs Holo")
plt.legend()
plt.show()

# %% [markdown]
# #### Why is it so bad? A deeper dive into the distributions...

# %%
lg, sm, lg_y, sm_y = train_test_split(stats_df, stats_df[['bound', 'reindex']], test_size=0.05, stratify=stats_df[['bound', 'reindex']])

# %%
sm = sm.sort_values(by='bound', ascending=False).reset_index(drop=True)

# %%
fig, ax = plt.subplots(10, 4, figsize=(12, 20))
for i in range(40):
    
    cur_sample = sm.loc[i]['sample']
    
    diff_map = rs.read_mtz(f'../PTP1B_DK/recons_mtzs/PTP1B-y{cur_sample}_mrflagsref_idxs_recons.mtz')[["F-obs-diff", "PHIFOFCWT"]].dropna()   

    diff_map_gemmi=diff_map.to_gemmi()
    diff_map_grid = diff_map_gemmi.transform_f_phi_to_map("F-obs-diff", "PHIFOFCWT", sample_rate=3)
    diff_map_grid.normalize()
    
    ax[i // 4][i % 4].hist(np.array(diff_map_grid).flatten(), bins=100, label=f'bound: {sm.loc[i]["bound"]}')
    
    
    
    ax[i // 4][i % 4].set_yscale("log")
    ax[i // 4][i % 4].set_xlabel("Sigma")
    ax[i // 4][i % 4].set_title(f'sample: {cur_sample}')
    ax[i // 4][i % 4].legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving Stats (Skew + Kurtosis)

# %%
stats_df.sort_values(by="kurtosis", ascending=False).head(50)
# Out:
#      sample  reindex  bound          mean   sd      skew   kurtosis
# 451    0562        0      0  8.585031e-10  1.0  0.890992  26.332282
# 978    1194        1      0 -1.448724e-10  1.0  0.782997  24.728698
# 1495   1797        0      0 -8.585031e-10  1.0  0.764349  18.760547
# 50     0060        0      1  3.932251e-10  1.0  0.565029  16.089233
# 1287   1554        0      1  3.543029e-10  1.0  0.497533  13.448816
# 34     0043        1      0  2.173086e-10  1.0  0.409590  10.896392
# 1235   1492        1      1 -4.139212e-11  1.0  0.525567   9.173682
# 196    0226        1      0  1.552204e-10  1.0  0.422047   8.856756
# 1338   1608        0      1  1.098884e-09  1.0  0.597229   8.626728
# 1348   1618        1      1 -2.316596e-10  1.0  0.379820   8.574257
# 920    1125        1      1  0.000000e+00  1.0  0.553901   8.049390
# 1450   1737        1      0 -2.112190e-10  1.0  0.423798   7.828629
# 663    0827        1      0 -8.241630e-10  1.0  0.310248   7.522030
# 228    0270        0      0 -4.676798e-10  1.0  0.476354   6.712961
# 1388   1659        1      0 -5.595601e-10  1.0  0.292015   6.295550
# 816    1003        0      0  2.845325e-10  1.0  0.363335   6.147998
# 950    1157        1      0 -9.313226e-10  1.0  0.453628   5.847338
# 178    0207        1      0 -7.195074e-11  1.0  0.281166   5.815258
# 559    0693        0      0 -1.086543e-09  1.0  0.185346   5.545766
# 88     0107        1      0 -5.110138e-11  1.0  0.311736   4.745787
# 1176   1417        0      1 -3.086523e-10  1.0  0.389497   4.699416
# 1498   1801        0      0 -2.912778e-10  1.0  0.180378   3.912572
# 1600   1935        0      0 -2.725407e-11  1.0  0.264932   3.644447
# 1217   1469        1      0  6.312297e-10  1.0  0.213569   3.289153
# 1141   1376        1      0  8.019722e-10  1.0  0.188200   3.288440
# 1107   1335        0      1 -1.138283e-10  1.0  0.165240   3.245334
# 1510   1814        0      0 -5.345286e-10  1.0  0.147803   3.228018
# 1346   1616        0      0  2.276566e-10  1.0  0.563022   3.045953
# 25     0032        0      0  1.513878e-10  1.0  0.190290   3.004311
# 1492   1793        0      0  1.839650e-10  1.0 -0.045686   2.975995
# 680    0845        0      1 -3.085246e-10  1.0  0.310452   2.939984
# 1085   1312        1      1 -2.867128e-08  1.0  0.438366   2.842980
# 481    0597        0      0  8.176220e-11  1.0  0.156698   2.816356
# 1247   1505        1      0  2.501923e-11  1.0  0.049615   2.617546
# 487    0604        1      0 -3.932251e-10  1.0  0.229427   2.565406
# 783    0965        0      1 -7.147805e-10  1.0  0.257378   2.391723
# 58     0072        0      1  5.178273e-10  1.0 -0.012746   2.329133
# 1591   1924        0      0  4.769461e-10  1.0  0.145733   2.303929
# 1404   1678        1      0 -1.422854e-10  1.0  0.578391   2.297926
# 1069   1295        1      0  3.270488e-11  1.0  0.093893   2.227268
# 703    0871        1      0 -2.682822e-10  1.0  0.313327   2.200168
# 89     0108        0      0  4.905732e-11  1.0 -0.132212   2.022297
# 1188   1429        0      1 -2.354751e-10  1.0  0.229500   2.017572
# 1353   1624        1      0  1.210081e-10  1.0  0.127451   1.852878
# 1548   1868        1      1  5.927759e-10  1.0  0.105272   1.847880
# 1618   1957        1      1  3.642506e-10  1.0  0.107295   1.838802
# 1040   1264        1      1  3.832603e-10  1.0  0.157861   1.831616
# 153    0180        0      1  1.226433e-10  1.0  0.144180   1.819564
# 450    0561        1      0 -2.725407e-11  1.0  0.181289   1.812615
# 384    0462        1      0  2.060407e-11  1.0  0.152066   1.808346

# %%
by_kurtosis = stats_df.sort_values(by="kurtosis", ascending=False).reset_index(drop=True)

# %%
by_skew = stats_df.sort_values(by="skew", ascending=False).reset_index(drop=True)

# %%
stats_df.to_pickle('../PTP1B_DK/stats/stats_df.pkl')
by_kurtosis.to_pickle('../PTP1B_DK/stats/stats_df_by_kurtosis.pkl')
by_skew.to_pickle('../PTP1B_DK/stats/stats_df_by_skew.pkl')

# %% [markdown]
# ### CDFs (Skew + Kurtosis)

# %%
stats_df = pd.read_pickle('../PTP1B_DK/stats/stats_df.pkl')
by_kurtosis = pd.read_pickle('../PTP1B_DK/stats/stats_df_by_kurtosis.pkl')
by_skew = pd.read_pickle('../PTP1B_DK/stats/stats_df_by_skew.pkl')

# %%
by_kurtosis['bound_cdf'] = by_kurtosis['bound'].cumsum() / np.sum(by_kurtosis['bound'])

# %%
by_skew['bound_cdf'] = by_skew['bound'].cumsum() / np.sum(by_skew['bound'])

# %%
plt.plot(by_kurtosis.index / len(by_kurtosis), by_kurtosis['bound_cdf'],
        label=f'AUC: {round(auc(by_kurtosis.index / len(by_kurtosis), by_kurtosis["bound_cdf"]), 3)}')
plt.ylabel('% Bound States')
plt.xlabel('Kurtosis Quantile')
plt.legend()
plt.show()

# %%
plt.plot(by_skew.index / len(by_skew), by_skew['bound_cdf'], 
         label=f'AUC: {round(auc(by_skew.index / len(by_skew), by_skew["bound_cdf"]), 3)}')
plt.ylabel('% Bound States')
plt.xlabel('Skew Quantile')
plt.legend()
plt.show()

# %% [markdown]
# #### AUC Curves

# %%
from sklearn import metrics

# %%
fpr, tpr, thresholds = metrics.roc_curve(by_kurtosis["bound"], by_kurtosis["kurtosis"], pos_label=1)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)

# %%
display.plot()

# %%
fpr, tpr, thresholds = metrics.roc_curve(by_skew["bound"], by_skew["skew"], pos_label=1)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)

# %%
display.plot()

# %% [markdown]
# #### Jarque Bera Test

# %%
stats_df['jarque_bera'] = stats_df['skew']**2+(1/4)*(stats_df['kurtosis'])**2
by_jarque_bera = stats_df.sort_values(by="jarque_bera", ascending=False).reset_index(drop=True)
by_jarque_bera.to_pickle('../PTP1B_DK/stats/stats_df_by_jarque_bera.pkl')

# %%
by_jarque_bera = pd.read_pickle('../PTP1B_DK/stats/stats_df_by_jarque_bera.pkl')

# %%
by_jarque_bera['bound_cdf'] = by_jarque_bera['bound'].cumsum() / np.sum(by_jarque_bera['bound'])

# %%
plt.plot(by_jarque_bera.index / len(by_jarque_bera), by_jarque_bera['bound_cdf'])
plt.ylabel('% Bound States')
plt.xlabel('Jarque Bera Quantile')
plt.show()

# %% [markdown]
# ### Differences Along Smiley (Skew + Kurtosis)

# %% [markdown]
# #### Find reconstructed PC values

# %%
recons_intersection = rs.read_mtz('../PTP1B_DK/recons_mtzs/intersection.mtz').T
# Out:
# /n/home10/phyllis/mambaforge/envs/rs/lib/python3.7/site-packages/reciprocalspaceship/io/mtz.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataset[c.label] = c.array

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(recons_intersection)
plt.scatter(principalComponents[:,0], principalComponents[:,1], c='blue', alpha=0.05)
plt.show()
# Out:
# /n/home10/phyllis/mambaforge/envs/rs/lib/python3.7/site-packages/sklearn/utils/validation.py:1679: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %%
recons_pc_values = pd.DataFrame(principalComponents, index=recons_intersection.index, columns=['PC1', 'PC2'])

# %%
recons_pc_values['sample'] = [x.split('_')[1] for x in recons_pc_values.index]
recons_pc_values = recons_pc_values[['sample', 'PC1', 'PC2']].reset_index(drop=True)

# %%
recons_pc_values.to_pickle('../PTP1B_DK/stats/recons_pc_values.pkl')

# %% [markdown]
# #### Relationship Between PC Value + (Skew / Kurtosis)

# %%
recons_pc_values = pd.read_pickle('../PTP1B_DK/stats/recons_pc_values.pkl')

# %%
by_kurtosis = pd.read_pickle('../PTP1B_DK/stats/stats_df_by_kurtosis.pkl')
by_skew = pd.read_pickle('../PTP1B_DK/stats/stats_df_by_skew.pkl')

# %%
by_kurtosis_pc = pd.merge(recons_pc_values, by_kurtosis, on=['sample'])
by_skew_pc = pd.merge(recons_pc_values, by_skew, on=['sample'])

# %%
plt.scatter(by_kurtosis_pc['PC1'], by_kurtosis_pc['kurtosis'], c='blue', alpha=0.1)
plt.ylabel('Kurtosis')
plt.xlabel('PC1 Value')
plt.show()

# %%
plt.scatter(by_kurtosis_pc['PC2'], by_kurtosis_pc['kurtosis'], c='blue', alpha=0.1)
plt.ylabel('Kurtosis')
plt.xlabel('PC2 Value')
plt.show()

# %%
plt.scatter(by_skew_pc['PC1'], by_skew_pc['skew'], c='blue', alpha=0.1)
plt.ylabel('Skew')
plt.xlabel('PC1 Value')
plt.show()

# %%
plt.scatter(by_skew_pc['PC2'], by_skew_pc['skew'], c='blue', alpha=0.1)
plt.ylabel('Skew')
plt.xlabel('PC2 Value')
plt.show()

# %% [markdown]
# #### PC Value of Mislabeled Kurtosis / Skew

# %%
top_20_kurtosis_bound_0 = by_kurtosis[by_kurtosis['bound'] == 0].head(20)
top_20_skew_bound_0 = by_skew[by_skew['bound'] == 0].head(20)

# %%
top_20_kurtosis_bound_0_pc = pd.merge(top_20_kurtosis_bound_0, recons_pc_values, on='sample')
top_20_skew_bound_0_pc = pd.merge(top_20_skew_bound_0, recons_pc_values, on='sample')

# %%
plt.scatter(recons_pc_values['PC1'], recons_pc_values['PC2'], alpha=0.1, c='b', label='All Datasets')
plt.scatter(top_20_skew_bound_0_pc['PC1'], top_20_skew_bound_0_pc['PC2'], alpha=1, c='y', label='Top 20 Skew, Unbound Label')
plt.scatter(top_20_kurtosis_bound_0_pc['PC1'], top_20_kurtosis_bound_0_pc['PC2'], c='r', label='Top 20 Kurtosis, Unbound Label')
plt.legend()
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
bottom_20_kurtosis_bound_1 = by_kurtosis[by_kurtosis['bound'] == 1].tail(20)
bottom_20_skew_bound_1 = by_skew[by_skew['bound'] == 1].tail(20)

# %%
bottom_20_kurtosis_bound_1_pc = pd.merge(bottom_20_kurtosis_bound_1, recons_pc_values, on='sample')
bottom_20_skew_bound_1_pc = pd.merge(bottom_20_skew_bound_1, recons_pc_values, on='sample')

# %%
plt.scatter(recons_pc_values['PC1'], recons_pc_values['PC2'], alpha=0.1, c='b', label='All Datasets')
plt.scatter(bottom_20_skew_bound_1_pc['PC1'], bottom_20_skew_bound_1_pc['PC2'], alpha=1, c='y', label='Bottom 20 Skew, Bound Label')
plt.scatter(bottom_20_kurtosis_bound_1_pc['PC1'], bottom_20_kurtosis_bound_1_pc['PC2'], c='r', label='Bottom 20 Kurtosis, Bound Label')
plt.legend()
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %% [markdown]
# ## Weights

# %%
stats_df = generate_diff_map_stats('../PTP1B_DK/weighted_mtzs/', 'weighted_F-obs-diff', 'PHIFOFCWT')
# Out:
#   0%|          | 0/1680 [00:00<?, ?it/s]

# %%
by_kurtosis = stats_df.sort_values(by="kurtosis", ascending=False).reset_index(drop=True)

# %%
by_skew = stats_df.sort_values(by="skew", ascending=False).reset_index(drop=True)

# %%
by_kurtosis['bound_cdf'] = by_kurtosis['bound'].cumsum() / np.sum(by_kurtosis['bound'])
plt.plot(by_kurtosis.index / len(by_kurtosis), by_kurtosis['bound_cdf'],
        label=f'AUC: {round(auc(by_kurtosis.index / len(by_kurtosis), by_kurtosis["bound_cdf"]), 3)}')
plt.ylabel('% Bound States')
plt.xlabel('Kurtosis Quantile')
plt.legend()
plt.show()

# %%
by_skew['bound_cdf'] = by_skew['bound'].cumsum() / np.sum(by_skew['bound'])
plt.plot(by_skew.index / len(by_skew), by_skew['bound_cdf'],
        label=f'AUC: {round(auc(by_skew.index / len(by_skew), by_skew["bound_cdf"]), 3)}')
plt.ylabel('% Bound States')
plt.xlabel('Skew Quantile')
plt.legend()
plt.show()

# %%
stats_df.to_pickle('../PTP1B_DK/stats/stats_df_weighted.pkl')
by_kurtosis.to_pickle('../PTP1B_DK/stats/stats_df_by_kurtosis_weighted.pkl')
by_skew.to_pickle('../PTP1B_DK/stats/stats_df_by_skew_weighted.pkl')

# %% [markdown]
# ## Identified Bound Correctly

# %%
peaks_df = generate_diff_map_blobs('../PTP1B_DK/recons_mtzs/', '../PTP1B_DK/pandda_input_models/', 'F-obs-diff', 'PHIFOFCWT')
# Out:
#   0%|          | 0/1683 [00:00<?, ?it/s]
# /n/home10/phyllis/mambaforge/envs/rs/lib/python3.7/site-packages/reciprocalspaceship/io/mtz.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataset[c.label] = c.array

# %%
path_to_models = '../PTP1B_DK/pandda_input_models/'
path_to_mtzs = '../PTP1B_DK/recons_mtzs/'
diff_col = 'F-obs-diff'
phase_col = 'PHIFOFCWT'

# %%
peaks = []
file_path = 'PTP1B-y0049_mrflagsref_idxs_recons.mtz'


# sample=rs.read_mtz('../PTP1B_DK/recons_mtzs/PTP1B-y0049_mrflagsref_idxs_recons.mtz')[["F-obs-diff", "PHIFOFCWT"]].dropna()
# structure = gemmi.read_pdb("../PTP1B_DK/bound_state_models/PTP1B-y0049_refmac_input.split.bound-state.pdb")

# sample_gemmi=sample.to_gemmi()
# grid = sample_gemmi.transform_f_phi_to_map("F-obs-diff", "PHIFOFCWT", sample_rate=3)
# grid.normalize()

# mean, sigma = np.mean(np.array(grid)), np.std(np.array(grid))

# # minimum requirements
# blobs = gemmi.find_blobs_by_flood_fill(grid, cutoff=5.5, min_volume=10, min_score=0, min_peak=7.5, negate=False)

diff_map = rs.read_mtz(path_to_mtzs + file_path)[[diff_col, phase_col]].dropna()

# read input model
structure = gemmi.read_pdb("../PTP1B_DK/bound_state_models/PTP1B-y0049_refmac_input.split.bound-state.pdb")

diff_map_gemmi=diff_map.to_gemmi()
grid = diff_map_gemmi.transform_f_phi_to_map(diff_col, phase_col, sample_rate=3)
grid.normalize()

mean, sigma = np.mean(np.array(grid)), np.std(np.array(grid))

# minimum requirements
blobs = gemmi.find_blobs_by_flood_fill(grid, cutoff=5.5, min_volume=10, min_score=0, min_peak=7.5, negate=True)

ns = gemmi.NeighborSearch(structure[0], structure.cell, 5).populate()
peaks = []
count = 0

for blob in blobs:
    #This is a list of weird pointer objects. It is safest to convert them `gemmi.CRA` objects (see below)
    marks = ns.find_atoms(blob.centroid)
    if len(marks) == 0:
        continue

    cra = dist = None
    for mark in marks:
        image_idx = mark.image_idx
        cra = mark.to_cra(structure[0])
        dist = structure.cell.find_nearest_pbc_image(blob.centroid, _cra.atom.pos, mark.image_idx).dist()

        record = {
            "sample"  :    sample,
            "bound"   :    1 if sample in bound_samples else 0,
            "reindex" :    0 if sample in reindexed["0"] else 1,
            "chain"   :    cra.chain.name,
            "seqid"   :    cra.residue.seqid.num,
            "residue" :    cra.residue.name,
            "atom"    :    cra.atom.name,
            "element" :    cra.atom.element.name,
            "dist"    :    dist,
            "peakz"   :    (blob.peak_value-mean)/sigma,
            "scorez"  :    (blob.score-mean)/sigma,
            "peak"    :    blob.peak_value,
            "score"   :    blob.score,
            "cenx"    :    blob.centroid.x,
            "ceny"    :    blob.centroid.y,
            "cenz"    :    blob.centroid.x,
            "coordx"  :    cra.atom.pos.x,
            "coordy"  :    cra.atom.pos.y,
            "coordz"  :    cra.atom.pos.z,
        }
        if negate:
            negative_keys = ['peak', 'peakz', 'score', 'scorez']
            for k in negative_keys:
                record[k] = -record[k]

    peaks.append(record)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_221732/2911192250.py in <module>
#      47         record = {
#      48             "sample"  :    sample,
# ---> 49             "bound"   :    1 if sample in bound_samples else 0,
#      50             "reindex" :    0 if sample in reindexed["0"] else 1,
#      51             "chain"   :    cra.chain.name,
#
# ~/mambaforge/envs/rs/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1533     def __nonzero__(self):
#    1534         raise ValueError(
# -> 1535             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1536             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1537         )
#
# ValueError: The truth value of a DataSet is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
blobs
# Out:
# []

# %%
blobs

# %%
sample=rs.read_mtz('../PTP1B_DK/recons_mtzs/PTP1B-y0049_mrflagsref_idxs_recons.mtz')[["F-obs-diff", "PHIFOFCWT"]].dropna()
structure = gemmi.read_pdb("../PTP1B_DK/bound_state_models/PTP1B-y0049_refmac_input.split.bound-state.pdb")

sample_gemmi=sample.to_gemmi()
grid = sample_gemmi.transform_f_phi_to_map("F-obs-diff", "PHIFOFCWT", sample_rate=3)

# %%
grid.array.shape
# Out:
# (144, 144, 192)

# %%
144*144*192
# Out:
# 3981312

# %%
# svd in reciprocal space (inpute zeroes)

# %%
by_kurtosis = pd.read_pickle('../PTP1B_DK/stats/stats_df_by_kurtosis.pkl')

# %%
by_kurtosis[by_kurtosis['reindex'] == 0].head(10)
# Out:
#    sample  reindex  bound          mean   sd      skew   kurtosis
# 0    0562        0      0  8.585031e-10  1.0  0.890992  26.332282
# 2    1797        0      0 -8.585031e-10  1.0  0.764349  18.760547
# 3    0060        0      1  3.932251e-10  1.0  0.565029  16.089233
# 4    1554        0      1  3.543029e-10  1.0  0.497533  13.448816
# 8    1608        0      1  1.098884e-09  1.0  0.597229   8.626728
# 13   0270        0      0 -4.676798e-10  1.0  0.476354   6.712961
# 15   1003        0      0  2.845325e-10  1.0  0.363335   6.147998
# 18   0693        0      0 -1.086543e-09  1.0  0.185346   5.545766
# 20   1417        0      1 -3.086523e-10  1.0  0.389497   4.699416
# 21   1801        0      0 -2.912778e-10  1.0  0.180378   3.912572

# %%
# 1554: 2 signals (surface site & at C215)

# %%
ligand_cif[ligand_cif['Dataset'] == 'PTP1B-y0270']
# Out:
#          Dataset             Ligands  Apo
# 261  PTP1B-y0270  [FMOPL000318a.cif]    0
