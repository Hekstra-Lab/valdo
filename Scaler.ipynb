# %%
import sys
sys.path.append("./src/")

from scaling import Scaler

# %%
import glob
file_list = glob.glob("../data/mtzs_reindex/*mtz")
file_list.sort()

# %%
scaler = Scaler(file_list[0])

# %%
scaler.batch_scaling(file_list[1:20], outputmtz_path="./scaled_mtzs/", verbose=True)
# Out:
# LS before:  3338166.2 LS after: 1198114
# Corr before:  0.955 Corr after: 0.955
# Time: 0.390
# ...
# LS before:  9513400.0 LS after: 566091
# Corr before:  0.980 Corr after: 0.980
# Time: 0.393
# ...
# LS before:  6935062.0 LS after: 4335682
# Corr before:  0.873 Corr after: 0.873
# Time: 0.257
# ...
# LS before:  1879378.0 LS after: 93888
# Corr before:  0.996 Corr after: 0.996
# Time: 0.377
# ...
# LS before:  235908.3 LS after: 57377
# Corr before:  0.998 Corr after: 0.998
# Time: 0.628
# ...
# LS before:  3396617.2 LS after: 794055
# Corr before:  0.974 Corr after: 0.974
# Time: 0.335
# ...
# LS before:  3484798.0 LS after: 53543
# Corr before:  0.998 Corr after: 0.998
# Time: 0.577
# ...
# LS before:  2435794.0 LS after: 204601
# Corr before:  0.992 Corr after: 0.992
# Time: 0.264
# ...
# LS before:  1581502.8 LS after: 165769
# Corr before:  0.997 Corr after: 0.997
# Time: 0.322
# ...
# LS before:  1575398.4 LS after: 738561
# Corr before:  0.979 Corr after: 0.979
# Time: 0.221
# ...
# LS before:  3313514.2 LS after: 1868091
# ...
